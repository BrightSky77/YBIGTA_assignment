# %% [markdown]
# ### RNN 세션은 코드 과제가 **없습니다**.
# ### Github에는 아래 질문에 대한 대답만 채워서, ipynb 파일을 업로드해 주세요.

# %% [markdown]
# ### Question 1.
# - Input 데이터가 sequence가 아닌 경우에, RNN은 그 구조상 input 데이터를 직접 입력으로 받아서 처리할 수는 없습니다. 대신에 해당 input의 특징들을 담고 있는 벡터의 형태로 변환하여 RNN input으로 제공할 수 있습니다. 이러한 벡터를 뭐라고 하나요?
# - 힌트: <br/>
# ![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Answer 1.
# 정답: Embedded vectors by Embedding

# %% [markdown]
# ### Question 2.
# - Vanishing gradient 문제는 긴 시퀀스를 모델링할 때, 비교적 멀리 떨어진 timestep에서의 gradient가 충분히 전달되지 못해 goldfish memory와 같은 현상을 유발했습니다. Vanilla RNN에서의 이러한 문제를 해결하기 위해 제시된 RNN의 변형 구조 두 가지를 예시로 들어 주세요.

# %% [markdown]
# ### Answer 2.
#
# # 제가 저번 과제도 서술형에서 영어로 답을 했는데 요세 영작 연습중이여서 이번에도 영작으로 해보려고 합니다.
# 정답:
# 1) LSTM
# ![image.png](data:image/png;base64,...)
#
# <image source - https://colah.github.io/posts/2015-08-Understanding-LSTMs/>
#
# ![image.png](data:image/png;base64,...)
#
# f is a function of sigmoid. If f gets closer to 1 , this means that the value of gradient shown above would not be vanished. Also the value of f can't be greater than 1 which means it prevents value exploding.

# %% [markdown]
# 2) GRU
#
# GRU only has reset gate and update gate . The update gates decide the amount of informatoin to pass through futurue process. This process makes the model to avoid gradient vanishing problems by copying all the information from past.
# ![image.png](data:image/png;base64,...)
#
# <image source - https://wikidocs.net/22889>
